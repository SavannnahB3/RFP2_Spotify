# %%
import json
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import MiniBatchKMeans

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load the dataset
with open('mpd.slice.0-999.json', 'r') as f:
    data = json.load(f)

# %%
# Extract text data from the dataset
texts = [playlist['name'] for playlist in data['playlists']]

# %%
# Vectorize the text data using TF-IDF
vectorizer = TfidfVectorizer(max_df=0.5, min_df=2, stop_words='english')
X = vectorizer.fit_transform(texts)

# %%
# Perform Mini-Batch K-Means clustering
num_clusters = 5  # You can adjust this number as per your requirement
batch_size = 100  # You can adjust the batch size
kmeans = MiniBatchKMeans(n_clusters=num_clusters, batch_size=batch_size, random_state=42)
kmeans.fit(X)
# Out:
# MiniBatchKMeans(batch_size=100, n_clusters=5, random_state=42)

# %%
# Print the top terms per cluster
print("Top terms per cluster:")
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(num_clusters):
    print(f"Cluster {i+1}:")
    for ind in order_centroids[i, :10]:
        print(f"   {terms[ind]}")
# Out:
# Top terms per cluster:
# Cluster 1:
#    songs
#    rock
#    oldies
#    classic
#    dance
#    lit
#    workout
#    gym
#    running
#    favorite
# Cluster 2:
#    summer
#    playlist
#    new
#    rap
#    christmas
#    good
#    mix
#    jams
#    feels
#    disney
# Cluster 3:
#    music
#    work
#    christmas
#    studying
#    christian
#    dance
#    wedding
#    new
#    electronic
#    relaxing
# Cluster 4:
#    country
#    old
#    mix
#    favorites
#    summer
#    2017
#    classic
#    day
#    deep
#    disney
# Cluster 5:
#    chill
#    party
#    hits
#    slow
#    gospel
#    throwback
#    roadtrip
#    mixtape
#    vibin
#    sleep
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Assign cluster labels to each playlist
cluster_labels = kmeans.labels_

# %%
# Print the cluster labels for each playlist
for i, playlist in enumerate(data['playlists']):
    print(f"Playlist: {playlist['name']}, Cluster: {cluster_labels[i]}")
# Out:
# Playlist: Throwbacks, Cluster: 1
# Playlist: Awesome Playlist, Cluster: 1
# Playlist: korean , Cluster: 4
# Playlist: mat, Cluster: 4
# Playlist: 90s, Cluster: 4
# Playlist: Wedding, Cluster: 1
# Playlist: I Put A Spell On You, Cluster: 4
# Playlist: 2017, Cluster: 4
# Playlist: BOP, Cluster: 4
# Playlist: old country , Cluster: 3
# Playlist: abby , Cluster: 4
# Playlist: VIBE, Cluster: 4
# Playlist: relax, Cluster: 4
# Playlist: sleep, Cluster: 4
# Playlist: 90's , Cluster: 4
# Playlist: New Songs, Cluster: 0
# Playlist: slow hands, Cluster: 4
# Playlist: Mom's playlist, Cluster: 1
# Playlist: SARAH, Cluster: 4
# Playlist: melancholy, Cluster: 4
# Playlist: mixtape, Cluster: 4
# Playlist: Sad Songs, Cluster: 0
# Playlist: fall '17, Cluster: 1
# Playlist: ✔️, Cluster: 4
# Playlist: Twenty one pilots, Cluster: 4
# Playlist: run it, Cluster: 1
# Playlist: Winter 2014, Cluster: 4
# Playlist: smooth , Cluster: 4
# Playlist: Yeet, Cluster: 4
# Playlist: groovy, Cluster: 4
# Playlist: Garage Rock, Cluster: 0
# Playlist: Running 2.0, Cluster: 0
# Playlist: acoustic, Cluster: 4
# Playlist: morning, Cluster: 4
# Playlist: good good, Cluster: 1
# Playlist: Good Vibes, Cluster: 1
# Playlist:  indie rock, Cluster: 0
# Playlist: Hits, Cluster: 4
# Playlist: tb, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: 2020, Cluster: 4
# Playlist: Belters, Cluster: 4
# Playlist: Road Trippin', Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: taylor swift, Cluster: 4
# Playlist: angst, Cluster: 4
# Playlist: Running 2, Cluster: 0
# Playlist: Spring 2016, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: Gospel, Cluster: 4
# Playlist: SB, Cluster: 4
# Playlist: Kevin, Cluster: 4
# Playlist: Christmas, Cluster: 1
# Playlist: NB, Cluster: 4
# Playlist: Smooth Jazz, Cluster: 4
# Playlist: Tennessee , Cluster: 4
# Playlist: funky, Cluster: 4
# Playlist: spring 16, Cluster: 4
# Playlist: Gates, Cluster: 4
# Playlist: Favorite Songs, Cluster: 0
# Playlist: Ski, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: hype, Cluster: 4
# Playlist: Awesome Mix, Cluster: 1
# Playlist: Elizabeth, Cluster: 4
# Playlist: PlayStation, Cluster: 4
# Playlist: Ashley, Cluster: 4
# Playlist: chill, Cluster: 4
# Playlist: xx, Cluster: 4
# Playlist: art class, Cluster: 4
# Playlist: Random Tunes, Cluster: 4
# Playlist: boat, Cluster: 4
# Playlist: spanish jams, Cluster: 1
# Playlist: new, Cluster: 1
# Playlist: CR, Cluster: 4
# Playlist: Run!!, Cluster: 1
# Playlist: winter '17, Cluster: 4
# Playlist: Workout, Cluster: 0
# Playlist: Traps , Cluster: 4
# Playlist: Dope, Cluster: 4
# Playlist: Chill, Cluster: 4
# Playlist: rap, Cluster: 1
# Playlist: Gospel, Cluster: 4
# Playlist: Florida, Cluster: 4
# Playlist: Workout2, Cluster: 4
# Playlist: Gym, Cluster: 0
# Playlist: Zoned, Cluster: 4
# Playlist: relax, Cluster: 4
# Playlist: KPOP, Cluster: 4
# Playlist: 80's, Cluster: 4
# Playlist: For the Road, Cluster: 4
# Playlist: R & B, Cluster: 4
# Playlist: Tom Petty, Cluster: 4
# Playlist: Catchy Songs, Cluster: 0
# Playlist: relax, Cluster: 4
# Playlist: roadtrippin, Cluster: 4
# Playlist: christmas, Cluster: 1
# Playlist: 2012, Cluster: 4
# Playlist: Dave, Cluster: 4
# Playlist: bang bang. , Cluster: 4
# Playlist: Disneyland, Cluster: 4
# Playlist: #boostyourrun, Cluster: 4
# Playlist: LUV, Cluster: 4
# Playlist: latin, Cluster: 4
# Playlist: JAMS, Cluster: 1
# Playlist: ~Rando~, Cluster: 4
# Playlist: Party Rock!!, Cluster: 0
# Playlist: party people, Cluster: 4
# Playlist: The Piano Guys, Cluster: 4
# Playlist: Worship, Cluster: 1
# Playlist: Brasileiras, Cluster: 4
# Playlist: country, Cluster: 3
# Playlist: 4/20, Cluster: 4
# Playlist: 2016, Cluster: 1
# Playlist: Willie, Cluster: 4
# Playlist: beach, Cluster: 4
# Playlist: Gold Digger, Cluster: 4
# Playlist: Fall 2015, Cluster: 1
# Playlist: dance it out, Cluster: 0
# Playlist: greek, Cluster: 4
# Playlist: All the songs, Cluster: 0
# Playlist: Kyle, Cluster: 4
# Playlist: HALLOWEEN, Cluster: 4
# Playlist: w o r k o u t, Cluster: 4
# Playlist: party music, Cluster: 2
# Playlist: summer, Cluster: 1
# Playlist: XXXMas, Cluster: 4
# Playlist: BBG, Cluster: 4
# Playlist: bae, Cluster: 4
# Playlist: oldies, Cluster: 0
# Playlist: its lit, Cluster: 0
# Playlist: go to, Cluster: 4
# Playlist: Killin' It, Cluster: 4
# Playlist: October 2017, Cluster: 4
# Playlist: Rap/Pop, Cluster: 1
# Playlist: 1990's , Cluster: 4
# Playlist: Rap, Cluster: 1
# Playlist: GUACAMOLE, Cluster: 4
# Playlist: 14, Cluster: 4
# Playlist: That New New, Cluster: 1
# Playlist: Relaxing, Cluster: 4
# Playlist: sleep, Cluster: 4
# Playlist: Get It!, Cluster: 4
# Playlist: bumps, Cluster: 4
# Playlist: picks, Cluster: 4
# Playlist: 🤘🏼, Cluster: 4
# Playlist: Mashup, Cluster: 4
# Playlist: Ladies, Cluster: 4
# Playlist: Alt Jams, Cluster: 1
# Playlist: Reggae/Ska, Cluster: 4
# Playlist: Top hits, Cluster: 4
# Playlist: jazzy , Cluster: 4
# Playlist: Pop, Cluster: 4
# Playlist: Emotional, Cluster: 4
# Playlist: Fall, Cluster: 4
# Playlist: ouch, Cluster: 4
# Playlist: Love Music, Cluster: 2
# Playlist: Bang Bang , Cluster: 4
# Playlist: Solitude, Cluster: 4
# Playlist: feels, Cluster: 1
# Playlist: Silence, Cluster: 4
# Playlist: English , Cluster: 4
# Playlist: Blues, Cluster: 4
# Playlist: pump, Cluster: 4
# Playlist: volleyball playlist , Cluster: 1
# Playlist: september , Cluster: 4
# Playlist: motown, Cluster: 4
# Playlist: folky, Cluster: 4
# Playlist: Rock alternativo, Cluster: 0
# Playlist: Summer Chill, Cluster: 1
# Playlist: Rap Classics, Cluster: 1
# Playlist: My favs, Cluster: 4
# Playlist: motivational , Cluster: 4
# Playlist: Up Beat, Cluster: 4
# Playlist: Wes Anderson, Cluster: 4
# Playlist: Love, Cluster: 4
# Playlist: basic, Cluster: 4
# Playlist: Another, Cluster: 4
# Playlist: LIT!!!!!!!, Cluster: 0
# Playlist: YEET, Cluster: 4
# Playlist: 🤤🤤, Cluster: 4
# Playlist: Summer Playlist, Cluster: 1
# Playlist: high, Cluster: 4
# Playlist: Music, Cluster: 2
# Playlist: Chill Alternative, Cluster: 4
# Playlist: feelz, Cluster: 4
# Playlist: Alexia, Cluster: 4
# Playlist: Mellow., Cluster: 4
# Playlist: Britt, Cluster: 4
# Playlist: Christian Songs, Cluster: 0
# Playlist: Kendrick Lamar , Cluster: 4
# Playlist: jesus jams, Cluster: 1
# Playlist: Daddy Issues, Cluster: 4
# Playlist: 🔥🔥🔥🔥, Cluster: 4
# Playlist: sb2k17, Cluster: 4
# Playlist: Dance, Cluster: 0
# Playlist: 2013, Cluster: 4
# Playlist: Spring16, Cluster: 4
# Playlist: soul, Cluster: 4
# Playlist: Best Songs of 2016, Cluster: 0
# Playlist: Ladies, Cluster: 4
# Playlist: Love , Cluster: 4
# Playlist: Cash, Cluster: 4
# Playlist: #Workout, Cluster: 0
# Playlist: guitar., Cluster: 4
# Playlist: running , Cluster: 0
# Playlist: Shower, Cluster: 4
# Playlist: Saturn, Cluster: 4
# Playlist: Christmas music, Cluster: 2
# Playlist: Bus playlist, Cluster: 1
# Playlist: Xmas, Cluster: 4
# Playlist: My music, Cluster: 2
# Playlist: Latino, Cluster: 4
# Playlist: Mumford & Sons, Cluster: 4
# Playlist: This Is What You Came For, Cluster: 4
# Playlist: On the Run, Cluster: 1
# Playlist: Prayer, Cluster: 4
# Playlist: my country, Cluster: 3
# Playlist: party playlist, Cluster: 1
# Playlist: Funky, Cluster: 4
# Playlist: Musicals, Cluster: 4
# Playlist: Relax, Cluster: 4
# Playlist: Wedding, Cluster: 1
# Playlist: classics, Cluster: 4
# Playlist: Peace, Cluster: 4
# Playlist: Volleyball, Cluster: 4
# Playlist: Madness, Cluster: 4
# Playlist: ride, Cluster: 4
# Playlist: before my time, Cluster: 1
# Playlist: reggae, Cluster: 4
# Playlist: Summer of love, Cluster: 1
# Playlist: Everything, Cluster: 4
# Playlist: Hits, Cluster: 4
# Playlist: shower , Cluster: 4
# Playlist: RUNNIN, Cluster: 4
# Playlist: My happy place, Cluster: 4
# Playlist: 90s hits, Cluster: 4
# Playlist: Old songs, Cluster: 0
# Playlist: Korean, Cluster: 4
# Playlist: Go to , Cluster: 4
# Playlist: Way Up, Cluster: 4
# Playlist: Tegan and Sara, Cluster: 4
# Playlist: Atlas, Cluster: 4
# Playlist: Elisa, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: 90s, Cluster: 4
# Playlist: eurotrip, Cluster: 4
# Playlist: Mine, Cluster: 4
# Playlist: Christmas 2016, Cluster: 1
# Playlist: Summer, Cluster: 1
# Playlist: TBT, Cluster: 4
# Playlist: beachy, Cluster: 4
# Playlist: country, Cluster: 3
# Playlist: Drank, Cluster: 4
# Playlist: Trip, Cluster: 4
# Playlist: Christmas Mix, Cluster: 1
# Playlist: TOP, Cluster: 4
# Playlist: rap god, Cluster: 1
# Playlist: #Relaxed, Cluster: 4
# Playlist: blue grass, Cluster: 4
# Playlist: brad paisley , Cluster: 4
# Playlist: summer16, Cluster: 4
# Playlist: throwback, Cluster: 4
# Playlist: love, Cluster: 4
# Playlist: DA, Cluster: 4
# Playlist: SUMMER 2k17, Cluster: 1
# Playlist: Awesome mix vol. 1, Cluster: 1
# Playlist: POP, Cluster: 4
# Playlist: Road Trip Mix, Cluster: 1
# Playlist: Indie, Cluster: 4
# Playlist: Corridos, Cluster: 4
# Playlist: Mr. Brightside, Cluster: 4
# Playlist: shower, Cluster: 4
# Playlist: workout, Cluster: 0
# Playlist: old people, Cluster: 4
# Playlist: FUN, Cluster: 4
# Playlist: 😍😍, Cluster: 4
# Playlist: Hockey, Cluster: 4
# Playlist: dank memes, Cluster: 4
# Playlist: 🎵🎵, Cluster: 4
# Playlist: Legendary, Cluster: 4
# Playlist: mayer, Cluster: 4
# Playlist: Game Time, Cluster: 1
# Playlist: car tunes, Cluster: 4
# Playlist: lit, Cluster: 0
# Playlist: wrap, Cluster: 4
# Playlist: Chris, Cluster: 4
# Playlist: chill beats, Cluster: 4
# Playlist: kpop, Cluster: 4
# Playlist: mix, Cluster: 1
# Playlist: Blackout, Cluster: 4
# Playlist: country , Cluster: 3
# Playlist: Disney, Cluster: 1
# Playlist: CHRISTMASSSSS, Cluster: 4
# Playlist: Aux, Cluster: 4
# Playlist: best christmas, Cluster: 1
# Playlist: Worship , Cluster: 1
# Playlist: broadway, Cluster: 4
# Playlist: Vibe, Cluster: 4
# Playlist: Say My Name, Cluster: 4
# Playlist: car playlist, Cluster: 1
# Playlist: Music From Baz Luhrmann's Film The Great Gatsby, Cluster: 2
# Playlist: deep, Cluster: 4
# Playlist: Tame Impala, Cluster: 4
# Playlist: <3, Cluster: 4
# Playlist: Running, Cluster: 0
# Playlist: mixtape, Cluster: 4
# Playlist: rawr, Cluster: 4
# Playlist: lit songs , Cluster: 0
# Playlist: upbeat, Cluster: 4
# Playlist: Good Day, Cluster: 1
# Playlist: AAA, Cluster: 4
# Playlist: Line Dances , Cluster: 4
# Playlist: Spanish, Cluster: 4
# Playlist: randoms, Cluster: 4
# Playlist: Alright, Cluster: 4
# Playlist: Feelin' Myself, Cluster: 4
# Playlist: RAP, Cluster: 1
# Playlist: Covers, Cluster: 4
# Playlist: Acoustic, Cluster: 4
# Playlist: chill, Cluster: 4
# Playlist: bruno mars, Cluster: 4
# Playlist: stream, Cluster: 4
# Playlist: mix , Cluster: 1
# Playlist: Me Like, Cluster: 4
# Playlist: Disney Jams, Cluster: 1
# Playlist: family, Cluster: 4
# Playlist: Walking on Sunshine, Cluster: 4
# Playlist: country, Cluster: 3
# Playlist: trap, Cluster: 4
# Playlist: electronic, Cluster: 4
# Playlist: The Drive, Cluster: 4
# Playlist: Julion alvarez, Cluster: 4
# Playlist: studying music, Cluster: 2
# Playlist: 90s alternative, Cluster: 4
# Playlist: Litty , Cluster: 4
# Playlist: oldies but goodies , Cluster: 0
# Playlist: More Songs, Cluster: 0
# Playlist: ((chris)), Cluster: 4
# Playlist: Worship, Cluster: 1
# Playlist: 🇲🇽🇲🇽🇲🇽, Cluster: 4
# Playlist: ( ͡° ͜ʖ ͡°), Cluster: 4
# Playlist: Dance mix, Cluster: 1
# Playlist: classic , Cluster: 0
# Playlist: oldies, Cluster: 0
# Playlist: NEW, Cluster: 1
# Playlist: Chill music , Cluster: 2
# Playlist: karaoke., Cluster: 4
# Playlist: ⚡️⚡️⚡️, Cluster: 4
# Playlist: Road, Cluster: 4
# Playlist: Latin Trap, Cluster: 4
# Playlist: Cali, Cluster: 4
# Playlist: frenchy, Cluster: 4
# Playlist: Thinking, Cluster: 4
# Playlist: Cruisin, Cluster: 4
# Playlist: throw backs, Cluster: 4
# Playlist: 2017, Cluster: 4
# Playlist: boris, Cluster: 4
# Playlist: Meow, Cluster: 4
# Playlist: old songs , Cluster: 0
# Playlist: pg, Cluster: 4
# Playlist: Breezeblocks, Cluster: 4
# Playlist: Favorite Songs, Cluster: 0
# Playlist: Classic Rock, Cluster: 0
# Playlist: Pregame, Cluster: 4
# Playlist: Chill Rock, Cluster: 0
# Playlist: High, Cluster: 4
# Playlist: Guilty pleasure, Cluster: 4
# Playlist: Everyday, Cluster: 4
# Playlist: Salsa clasica, Cluster: 4
# Playlist: CHRISTMAS, Cluster: 1
# Playlist: quiet, Cluster: 4
# Playlist: TRIPPIn, Cluster: 4
# Playlist: happy, Cluster: 4
# Playlist: oldies, Cluster: 0
# Playlist: Chill, Cluster: 4
# Playlist: Studying, Cluster: 4
# Playlist: Classic, Cluster: 0
# Playlist: country, Cluster: 3
# Playlist: Autumnal , Cluster: 4
# Playlist: Throwbacks , Cluster: 1
# Playlist: Traveling, Cluster: 4
# Playlist: spin, Cluster: 4
# Playlist: country 2017, Cluster: 3
# Playlist: *** good stuff, Cluster: 1
# Playlist: LM, Cluster: 4
# Playlist: Chill, Cluster: 4
# Playlist: sad, Cluster: 4
# Playlist: Party time, Cluster: 4
# Playlist: mb, Cluster: 4
# Playlist: Samba, Cluster: 4
# Playlist: tears., Cluster: 4
# Playlist: Go To, Cluster: 4
# Playlist: Friday afternoon..., Cluster: 4
# Playlist: songs that make me think of you , Cluster: 0
# Playlist: Congratulations, Cluster: 4
# Playlist: Party, Cluster: 4
# Playlist: Random, Cluster: 4
# Playlist: Comedy, Cluster: 4
# Playlist: RAVE, Cluster: 4
# Playlist: summer 2015, Cluster: 1
# Playlist: GET DOWN, Cluster: 4
# Playlist: JAZZ, Cluster: 4
# Playlist: Hype, Cluster: 4
# Playlist: ⚡️, Cluster: 4
# Playlist: in my feels, Cluster: 1
# Playlist: 90's, Cluster: 4
# Playlist: Piano Music, Cluster: 2
# Playlist: workout mix, Cluster: 1
# Playlist: 90s hip hop, Cluster: 4
# Playlist: Metal, Cluster: 4
# Playlist: ashley, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: Sweat.It.Out., Cluster: 4
# Playlist: early 2000's, Cluster: 4
# Playlist: Get pumped , Cluster: 4
# Playlist: West Coast Swing, Cluster: 4
# Playlist: Rock, Cluster: 0
# Playlist: june, Cluster: 4
# Playlist: Roadtrip, Cluster: 4
# Playlist: Smooth, Cluster: 4
# Playlist: 1967, Cluster: 4
# Playlist: Old School, Cluster: 4
# Playlist: New, Cluster: 1
# Playlist: WORSHIP, Cluster: 1
# Playlist: Phone, Cluster: 4
# Playlist: yo, Cluster: 4
# Playlist: PT, Cluster: 4
# Playlist: car rides, Cluster: 4
# Playlist: Music., Cluster: 2
# Playlist: Rent, Cluster: 4
# Playlist: Feels, Cluster: 1
# Playlist: goldie, Cluster: 4
# Playlist: Sad songs, Cluster: 0
# Playlist: DIEGO$, Cluster: 4
# Playlist: New years, Cluster: 1
# Playlist: Driving, Cluster: 4
# Playlist: April, Cluster: 4
# Playlist: OD, Cluster: 4
# Playlist: housewarming, Cluster: 4
# Playlist: car, Cluster: 4
# Playlist: chill out, Cluster: 4
# Playlist: rap mix, Cluster: 1
# Playlist: Kickin it, Cluster: 4
# Playlist: Chill Out, Cluster: 4
# Playlist: 90s baby, Cluster: 4
# Playlist: Oldies, Cluster: 0
# Playlist: Classical, Cluster: 4
# Playlist: My favorites, Cluster: 4
# Playlist: Hyphy, Cluster: 4
# Playlist: Pump up songs, Cluster: 0
# Playlist: Beautiful Things, Cluster: 4
# Playlist: dance, Cluster: 0
# Playlist: my heart, Cluster: 4
# Playlist: issa playlist, Cluster: 1
# Playlist: Party, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: roma, Cluster: 4
# Playlist: Intro, Cluster: 4
# Playlist: Dusk, Cluster: 4
# Playlist: slow, Cluster: 4
# Playlist: BUST A MOVE, Cluster: 4
# Playlist: Current jams, Cluster: 1
# Playlist: Fallout, Cluster: 4
# Playlist: 2017, Cluster: 4
# Playlist: Punk, Cluster: 4
# Playlist: Homework, Cluster: 4
# Playlist: 000, Cluster: 4
# Playlist: Good Times, Cluster: 1
# Playlist: new stuff, Cluster: 1
# Playlist: It's Christmas Time!, Cluster: 1
# Playlist: AA, Cluster: 4
# Playlist: Chill Sesh, Cluster: 4
# Playlist: SPRANG, Cluster: 4
# Playlist: Greatest Hits, Cluster: 4
# Playlist: elevator music, Cluster: 2
# Playlist: YOU, Cluster: 4
# Playlist: Reggaeton, Cluster: 4
# Playlist: Long Car Rides, Cluster: 4
# Playlist: Country favorites, Cluster: 3
# Playlist: Chill Out Music, Cluster: 2
# Playlist: Good songs, Cluster: 0
# Playlist: hip hop, Cluster: 4
# Playlist: vibes, Cluster: 4
# Playlist: INDY, Cluster: 4
# Playlist: 90's, Cluster: 4
# Playlist: ODESZA, Cluster: 4
# Playlist: Good stuff, Cluster: 1
# Playlist: CHRISTMAS MUSIC, Cluster: 2
# Playlist: Isis, Cluster: 4
# Playlist: My baby, Cluster: 4
# Playlist: Melting Pot, Cluster: 4
# Playlist: Eminem , Cluster: 4
# Playlist: Zombies, Cluster: 4
# Playlist: Mega Chill, Cluster: 4
# Playlist: OOOUUU, Cluster: 4
# Playlist: songs to sing in the shower, Cluster: 0
# Playlist: Narcos, Cluster: 4
# Playlist: modern rock, Cluster: 0
# Playlist: Wedding Dance Party, Cluster: 1
# Playlist: oldies, Cluster: 0
# Playlist: regaton , Cluster: 4
# Playlist: tbd, Cluster: 4
# Playlist: Instrumental, Cluster: 4
# Playlist: Old School , Cluster: 4
# Playlist: joSe :), Cluster: 4
# Playlist: 💃🏽, Cluster: 4
# Playlist: Feels, Cluster: 1
# Playlist: favs rn, Cluster: 4
# Playlist: Chill Songs, Cluster: 0
# Playlist: feels, Cluster: 1
# Playlist: 😻😻, Cluster: 4
# Playlist: Somber, Cluster: 4
# Playlist: Sunrise, Cluster: 4
# Playlist: Mix Tape, Cluster: 1
# Playlist: FNAF, Cluster: 4
# Playlist: smooth jams, Cluster: 1
# Playlist: Best EDM, Cluster: 1
# Playlist: Worship, Cluster: 1
# Playlist: hitS, Cluster: 4
# Playlist: 😭😭, Cluster: 4
# Playlist: music, Cluster: 2
# Playlist: Upbeat Songs , Cluster: 0
# Playlist: HOOD, Cluster: 4
# Playlist: poop, Cluster: 4
# Playlist: Tejano, Cluster: 4
# Playlist: Cinco De Mayo, Cluster: 4
# Playlist: Tripping, Cluster: 4
# Playlist: New School, Cluster: 1
# Playlist: now, Cluster: 4
# Playlist: Electronic Music, Cluster: 2
# Playlist: 2000's , Cluster: 4
# Playlist: Sleep, Cluster: 4
# Playlist: mix, Cluster: 1
# Playlist: New Music, Cluster: 2
# Playlist: halcyon, Cluster: 4
# Playlist: Wedding Cocktail Hour, Cluster: 1
# Playlist: chill  , Cluster: 4
# Playlist: february '17, Cluster: 1
# Playlist: July 2013, Cluster: 4
# Playlist: Musica en español, Cluster: 4
# Playlist: SpRiNg BrEaK, Cluster: 4
# Playlist: vibin', Cluster: 4
# Playlist: Rock, Cluster: 0
# Playlist: vibes, Cluster: 4
# Playlist: Tropical, Cluster: 4
# Playlist: pregame, Cluster: 4
# Playlist: whatever, Cluster: 4
# Playlist: Mix Tape, Cluster: 1
# Playlist: Thug, Cluster: 4
# Playlist: Winter, Cluster: 4
# Playlist: Sleep~, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: Reggae, Cluster: 4
# Playlist: Vibin, Cluster: 4
# Playlist: older songs, Cluster: 0
# Playlist: Crossfit, Cluster: 4
# Playlist: Work, Cluster: 4
# Playlist: Black, Cluster: 4
# Playlist: 💛💛, Cluster: 4
# Playlist: Summer Party, Cluster: 1
# Playlist: chillen, Cluster: 4
# Playlist: Country summer, Cluster: 3
# Playlist: Top Hits, Cluster: 4
# Playlist: cheese, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: Wedding, Cluster: 1
# Playlist: 14, Cluster: 4
# Playlist: NICOLE, Cluster: 4
# Playlist: Relaxing Music, Cluster: 2
# Playlist: run, Cluster: 1
# Playlist: Disney!, Cluster: 1
# Playlist: bounce, Cluster: 4
# Playlist: Calming Music, Cluster: 2
# Playlist: kayla, Cluster: 4
# Playlist: Party mix, Cluster: 1
# Playlist: wake up, Cluster: 4
# Playlist: sound, Cluster: 4
# Playlist: sad, Cluster: 4
# Playlist: Mya, Cluster: 4
# Playlist: rock, Cluster: 0
# Playlist: main playlist, Cluster: 1
# Playlist: doo wop, Cluster: 4
# Playlist: nite, Cluster: 4
# Playlist: Main, Cluster: 4
# Playlist: 🖕🏻, Cluster: 4
# Playlist: Wandering, Cluster: 4
# Playlist: Current, Cluster: 4
# Playlist: Wedding Dance Music, Cluster: 2
# Playlist: rap, Cluster: 1
# Playlist: Vibin', Cluster: 4
# Playlist: dad songs, Cluster: 0
# Playlist: 2015, Cluster: 1
# Playlist: PARTY PLAYLIST, Cluster: 1
# Playlist: bomb, Cluster: 4
# Playlist: spring '17, Cluster: 4
# Playlist: maY!, Cluster: 4
# Playlist: Baby Making, Cluster: 4
# Playlist: ale, Cluster: 4
# Playlist: Sunny Days, Cluster: 4
# Playlist: Stuff, Cluster: 1
# Playlist: Up, Cluster: 4
# Playlist: Happy Happy Happy, Cluster: 4
# Playlist: Don't, Cluster: 4
# Playlist: Lent, Cluster: 4
# Playlist: turn up, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: Songs I Like, Cluster: 0
# Playlist: Spring 2015, Cluster: 4
# Playlist: classic rock, Cluster: 0
# Playlist: 70/80, Cluster: 4
# Playlist: Oldies, Cluster: 0
# Playlist: summer 17, Cluster: 1
# Playlist: Wedding Songs, Cluster: 0
# Playlist: indie rock , Cluster: 0
# Playlist: Sierreño, Cluster: 4
# Playlist: study, Cluster: 4
# Playlist: Random, Cluster: 4
# Playlist: Christmastime, Cluster: 4
# Playlist: random songs, Cluster: 0
# Playlist: party, Cluster: 4
# Playlist: workout, Cluster: 0
# Playlist: mine, Cluster: 4
# Playlist: take me back, Cluster: 4
# Playlist: ROAR, Cluster: 4
# Playlist: old, Cluster: 4
# Playlist: teenage angst, Cluster: 4
# Playlist: Wave, Cluster: 4
# Playlist: Mixtape, Cluster: 4
# Playlist: 80s, Cluster: 4
# Playlist: //new, Cluster: 1
# Playlist: house, Cluster: 4
# Playlist: ol skool, Cluster: 4
# Playlist: music, Cluster: 2
# Playlist: ROCK🎸, Cluster: 0
# Playlist: Workout, Cluster: 0
# Playlist: go-to, Cluster: 4
# Playlist: Classic, Cluster: 0
# Playlist: Various Artists – Majestic Casual - Chapter I, Cluster: 4
# Playlist: Grind, Cluster: 4
# Playlist: America, Cluster: 4
# Playlist: sleep, Cluster: 4
# Playlist: rap, Cluster: 1
# Playlist: VACATION, Cluster: 4
# Playlist: christmas, Cluster: 1
# Playlist: Dubstep, Cluster: 1
# Playlist: Pop, Cluster: 4
# Playlist: Gym, Cluster: 0
# Playlist: Mia, Cluster: 4
# Playlist: Musica, Cluster: 4
# Playlist: Australia Day, Cluster: 4
# Playlist: Slay, Cluster: 4
# Playlist: II, Cluster: 4
# Playlist: Arab, Cluster: 4
# Playlist: Take Me Back, Cluster: 4
# Playlist: Christmas Time, Cluster: 1
# Playlist: feel good, Cluster: 1
# Playlist: 😈😈😈, Cluster: 4
# Playlist: Rock, Cluster: 0
# Playlist: Lifting , Cluster: 4
# Playlist: Panda, Cluster: 4
# Playlist: Car Party, Cluster: 4
# Playlist: discovered, Cluster: 4
# Playlist: 2000s hits, Cluster: 4
# Playlist: Workout, Cluster: 0
# Playlist: recommendations !! , Cluster: 4
# Playlist: eclipse, Cluster: 4
# Playlist: classical, Cluster: 4
# Playlist: Feel Good, Cluster: 1
# Playlist: summer 2k17, Cluster: 1
# Playlist: cake , Cluster: 4
# Playlist: lean, Cluster: 4
# Playlist: Chill, Cluster: 4
# Playlist: Say You Won't Let Go, Cluster: 4
# Playlist: Deep Thoughts, Cluster: 4
# Playlist: Dinner Party, Cluster: 4
# Playlist: Clubbin, Cluster: 4
# Playlist: For You, Cluster: 4
# Playlist: tb, Cluster: 4
# Playlist: Blues, Cluster: 4
# Playlist: Country Favorites, Cluster: 3
# Playlist: Work, Cluster: 4
# Playlist: twenty sixteen, Cluster: 4
# Playlist: Life , Cluster: 4
# Playlist: Waltz, Cluster: 4
# Playlist: uhhhh, Cluster: 4
# Playlist: Throwback, Cluster: 4
# Playlist: Cinderella, Cluster: 4
# Playlist: 😍😍😍, Cluster: 4
# Playlist: My Musics, Cluster: 4
# Playlist: Dark Side, Cluster: 4
# Playlist: Club, Cluster: 4
# Playlist: december, Cluster: 4
# Playlist: chill time, Cluster: 4
# Playlist: PARTY , Cluster: 4
# Playlist: three, Cluster: 4
# Playlist: Alternativo , Cluster: 4
# Playlist: Partay, Cluster: 4
# Playlist: rock songs, Cluster: 0
# Playlist: Lulu, Cluster: 4
# Playlist: Amy, Cluster: 4
# Playlist: Old songs , Cluster: 0
# Playlist: Wedding Cocktail Hour, Cluster: 1
# Playlist: ALT, Cluster: 4
# Playlist: Drake, Cluster: 4
# Playlist: Wedding, Cluster: 1
# Playlist: MY FAV, Cluster: 4
# Playlist: party, Cluster: 4
# Playlist: pop, Cluster: 4
# Playlist: winter, Cluster: 4
# Playlist: my favorite songs, Cluster: 0
# Playlist: yoga, Cluster: 4
# Playlist: classic, Cluster: 0
# Playlist: Cody, Cluster: 4
# Playlist: raw, Cluster: 4
# Playlist: Band Music, Cluster: 2
# Playlist: Rave, Cluster: 4
# Playlist: Throwbacks, Cluster: 1
# Playlist: Swing, Cluster: 4
# Playlist: CARDIO, Cluster: 4
# Playlist: PARTY 1, Cluster: 4
# Playlist: throwback, Cluster: 4
# Playlist: running, Cluster: 0
# Playlist: Wet Dreamz, Cluster: 4
# Playlist: roadtrip 🚗, Cluster: 4
# Playlist: Feels, Cluster: 1
# Playlist: dubstep, Cluster: 1
# Playlist: Rock en español , Cluster: 0
# Playlist: summer country, Cluster: 3
# Playlist: Pop, Cluster: 4
# Playlist: lit, Cluster: 0
# Playlist: Best of 2016, Cluster: 1
# Playlist: country, Cluster: 3
# Playlist: rap, Cluster: 1
# Playlist: 2000s r&b, Cluster: 4
# Playlist: my songs , Cluster: 0
# Playlist: Not Rap, Cluster: 1
# Playlist: fuego, Cluster: 4
# Playlist: spanish , Cluster: 4
# Playlist: Best, Cluster: 1
# Playlist: will, Cluster: 4
# Playlist: Chill, Cluster: 4
# Playlist: Holiday Party, Cluster: 4
# Playlist: New ish, Cluster: 1
# Playlist: Running, Cluster: 0
# Playlist: Mad Men, Cluster: 4
# Playlist: EBM, Cluster: 4
# Playlist: 2000s, Cluster: 4
# Playlist: Disney, Cluster: 1
# Playlist: Buena Vista Social Club, Cluster: 4
# Playlist: Summer 2016, Cluster: 1
# Playlist: xmas party, Cluster: 4
# Playlist: for you, Cluster: 4
# Playlist: Luke, Cluster: 4
# Playlist: L O V E , Cluster: 4
# Playlist: Summer Country, Cluster: 3
# Playlist: kitchen, Cluster: 4
# Playlist: Yeah, Cluster: 4
# Playlist: Britney, Cluster: 4
# Playlist: ghetto, Cluster: 4
# Playlist: HARDCORE WORKOUT, Cluster: 0
# Playlist: #mood, Cluster: 4
# Playlist: Gospel Mix, Cluster: 1
# Playlist: Turnt, Cluster: 4
# Playlist: GOOD MUSIC , Cluster: 2
# Playlist: Tangled, Cluster: 4
# Playlist: music, Cluster: 2
# Playlist: The Mix, Cluster: 1
# Playlist: Fun, Cluster: 4
# Playlist: Elliot, Cluster: 4
# Playlist: summer 2016, Cluster: 1
# Playlist: Classical favorites, Cluster: 4
# Playlist: no, Cluster: 4
# Playlist: 4th of july, Cluster: 4
# Playlist: Sugar, Cluster: 4
# Playlist: vibin, Cluster: 4
# Playlist: ha, Cluster: 4
# Playlist: christmas, Cluster: 1
# Playlist: electro, Cluster: 4
# Playlist: 00s, Cluster: 4
# Playlist: Rage, Cluster: 4
# Playlist: New jams, Cluster: 1
# Playlist: Main Playlist, Cluster: 1
# Playlist: Christmas, Cluster: 1
# Playlist: Cruising, Cluster: 4
# Playlist: Girl Power, Cluster: 4
# Playlist: Summer 2016, Cluster: 1
# Playlist: Baes, Cluster: 4
# Playlist: ATL, Cluster: 4
# Playlist: Soulful  , Cluster: 4
# Playlist: 😴😴, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: Pitch Perfect, Cluster: 4
# Playlist: feels, Cluster: 1
# Playlist: siesta, Cluster: 4
# Playlist: Shape of You, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: Workout, Cluster: 0
# Playlist: mellow, Cluster: 4
# Playlist: Helene, Cluster: 4
# Playlist: Christian music, Cluster: 2
# Playlist: Runaway, Cluster: 4
# Playlist: work music, Cluster: 2
# Playlist: Country, Cluster: 3
# Playlist: Good Stuff, Cluster: 1
# Playlist: car playlist , Cluster: 1
# Playlist: 2K14, Cluster: 4
# Playlist: Summer drives, Cluster: 1
# Playlist: 💸💸, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: road trip , Cluster: 4
# Playlist: musicals, Cluster: 4
# Playlist: Throwback, Cluster: 4
# Playlist: ease ~, Cluster: 4
# Playlist: Groovy, Cluster: 4
# Playlist: WORKOUT, Cluster: 0
# Playlist: Easy Listening , Cluster: 4
# Playlist: Cancun, Cluster: 4
# Playlist: Star Wars, Cluster: 4
# Playlist:  CHiLl, Cluster: 4
# Playlist: jan 2015, Cluster: 1
# Playlist: feel good, Cluster: 1
# Playlist: explicit, Cluster: 4
# Playlist: Broadway Baby, Cluster: 4
# Playlist: Worship, Cluster: 1
# Playlist: pregame, Cluster: 4
# Playlist: Hawaii, Cluster: 4
# Playlist: Roadtrip, Cluster: 4
# Playlist: .jams., Cluster: 1
# Playlist: The Classics, Cluster: 4
# Playlist: Heat, Cluster: 4
# Playlist: My hits, Cluster: 4
# Playlist: Fix You, Cluster: 4
# Playlist: I workout!, Cluster: 0
# Playlist: Disney, Cluster: 1
# Playlist: everything, Cluster: 4
# Playlist: boujee, Cluster: 4
# Playlist: Country Mix, Cluster: 3
# Playlist: bird, Cluster: 4
# Playlist: Camp, Cluster: 4
# Playlist: rap, Cluster: 1
# Playlist: Deb, Cluster: 4
# Playlist: christmas, Cluster: 1
# Playlist: 2016, Cluster: 1
# Playlist: nostalgia, Cluster: 4
# Playlist: english, Cluster: 4
# Playlist: empty, Cluster: 4
# Playlist: The Good Stuff, Cluster: 1
# Playlist: Local, Cluster: 4
# Playlist: chill, Cluster: 4
# Playlist: Lit🔥🔥, Cluster: 0
# Playlist: Indie Stuff, Cluster: 1
# Playlist: chill, Cluster: 4
# Playlist:  Frozen, Cluster: 4
# Playlist: HER, Cluster: 4
# Playlist: Gospel, Cluster: 4
# Playlist: songs to dance to, Cluster: 0
# Playlist: study, Cluster: 4
# Playlist: summer 16', Cluster: 1
# Playlist: Hungover, Cluster: 4
# Playlist: work, Cluster: 4
# Playlist: Christmas Favorites, Cluster: 1
# Playlist: mood music, Cluster: 2
# Playlist: good vibes, Cluster: 1
# Playlist: I like these songs, Cluster: 0
# Playlist: Cha Cha, Cluster: 4
# Playlist: Worship, Cluster: 1
# Playlist: PURPLE, Cluster: 4
# Playlist: April 2016, Cluster: 4
# Playlist: My Heart, Cluster: 4
# Playlist: recovery, Cluster: 4
# Playlist: space jams, Cluster: 1
# Playlist: bored, Cluster: 4
# Playlist: Volleyball, Cluster: 4
# Playlist: Mixed, Cluster: 4
# Playlist: Jammin, Cluster: 4
# Playlist: Chidas, Cluster: 4
# Playlist: ELECTRONICAS, Cluster: 4
# Playlist: new new, Cluster: 1
# Playlist: Country, Cluster: 3
# Playlist: Working Out, Cluster: 4
# Playlist: EDC, Cluster: 4
# Playlist: run 2, Cluster: 1
# Playlist: Office, Cluster: 4
# Playlist: Songs I Love, Cluster: 0
# Playlist: SEPTEMBER 2017, Cluster: 4
# Playlist: BUMP, Cluster: 4
# Playlist: Reception, Cluster: 4
# Playlist: Old Rock, Cluster: 0
# Playlist: Edward Sharpe & The Magnetic Zeros, Cluster: 4
# Playlist: Two, Cluster: 4
# Playlist: Good music , Cluster: 2
# Playlist: 1980's, Cluster: 4
# Playlist: Country, Cluster: 3
# Playlist: playlist, Cluster: 1
# Playlist: Throwbacks, Cluster: 1
# Playlist: Classic Country, Cluster: 3
# Playlist: Thuggin, Cluster: 4
# Playlist: trending, Cluster: 4
# Playlist: Relax, Cluster: 4
# Playlist: My High-Intensity Workout, Cluster: 4
# Playlist: Sundays, Cluster: 4
# Playlist: sunday, Cluster: 4
# Playlist: Oldies, Cluster: 0
# Playlist: dance yrself clean, Cluster: 0
# Playlist: Sleep Music, Cluster: 2
# Playlist: DISCOVER, Cluster: 4
# Playlist: Lit, Cluster: 0
# Playlist: old but good, Cluster: 1
# Playlist: Awesome, Cluster: 4
# Playlist: Pump up, Cluster: 4
# Playlist: BEST SONGS EVER, Cluster: 0
# Playlist: old school, Cluster: 4
# Playlist: PARTY, Cluster: 4
# Playlist: dance, Cluster: 0
# Playlist: Alternative, Cluster: 4
# Playlist: Rock, Cluster: 0
# Playlist: Summer '16, Cluster: 1
# Playlist: Pearl Jam, Cluster: 4
# Playlist: petrichor, Cluster: 4
# Playlist: LITT , Cluster: 4
# Playlist: Rock, Cluster: 0
# Playlist: Baby shower, Cluster: 4
# Playlist: beautiful, Cluster: 4
# Playlist: mine, Cluster: 4
# Playlist: John's Playlist, Cluster: 1
# Playlist: rock, Cluster: 0
# Playlist: Oldies, Cluster: 0
# Playlist: vibin, Cluster: 4
# Playlist: Move, Cluster: 4
# Playlist: Seduction, Cluster: 4
# Playlist: Fire, Cluster: 4
# Playlist: halloweenie, Cluster: 4
# Playlist: Reception, Cluster: 4
# Playlist: Love, Cluster: 4
# Playlist: Rock, Cluster: 0
# Playlist: Worship, Cluster: 1
# Playlist: hayley, Cluster: 4
# Playlist: Inspiration, Cluster: 4
# Playlist: <3, Cluster: 4
# Playlist: Playlist, Cluster: 1
# Playlist: 2k17, Cluster: 4
# Playlist: R&B classics, Cluster: 4
# Playlist: Fall 2015, Cluster: 1
# Playlist: hoe anthems, Cluster: 4
# Playlist: the mix, Cluster: 1
# Playlist: summer '17, Cluster: 1
# Playlist: nashville, Cluster: 4
# Playlist: Christmas songs , Cluster: 0
# Playlist: jamz, Cluster: 4
# Playlist: Summer 2016, Cluster: 1
# Playlist: stuff, Cluster: 1
# Playlist: The Greatest, Cluster: 4
# Playlist: #chill, Cluster: 4
# Playlist: country, Cluster: 3
# Playlist: country , Cluster: 3
# Playlist: Classical, Cluster: 4
# Playlist: disney bops, Cluster: 1
# Playlist: top down, Cluster: 4
# Playlist: Rap Songs, Cluster: 0
# Playlist: Chillout , Cluster: 4
# Playlist: Gospel, Cluster: 4
# Playlist: MERICA, Cluster: 4
# Playlist: Dubstep , Cluster: 1
# Playlist: KILLA, Cluster: 4
# Playlist: hey, Cluster: 4
# Playlist: mello, Cluster: 4
# Playlist: spanish, Cluster: 4
# Playlist: death, Cluster: 4
# Playlist: Marshall , Cluster: 4
# Playlist: Summer 2014, Cluster: 1
# Playlist: Rap it up, Cluster: 1
# Playlist: Slow Stuff, Cluster: 4
# Playlist: flow, Cluster: 4
# Playlist: Maui, Cluster: 4
# Playlist: Lit af, Cluster: 0
# Playlist: Neo, Cluster: 4
# Playlist: summer playlist, Cluster: 1
# Playlist: Dancehall, Cluster: 4
# Playlist: new, Cluster: 1
# Playlist: Gym, Cluster: 0
# Playlist: Chill, Cluster: 4
# Playlist: nc, Cluster: 4
# Playlist: 2pac, Cluster: 4
# Playlist: Pump up, Cluster: 4
# Playlist: Party Playlist, Cluster: 1
# Playlist: New Music, Cluster: 2
# Playlist: Dancing on my own, Cluster: 4
# Playlist: New, Cluster: 1
# Playlist: David, Cluster: 4
# Playlist: Michelle , Cluster: 4
# Playlist: Bad and Boujee, Cluster: 4
# Playlist: R&B, Cluster: 4
# Playlist: 🌈🌈🌈, Cluster: 4
# Playlist: FALL 2013, Cluster: 4
# Playlist: old, Cluster: 4
# Playlist: Daze, Cluster: 4
# Playlist: rap, Cluster: 1
# Playlist: Country, Cluster: 3
# Playlist: thinking of you, Cluster: 4
