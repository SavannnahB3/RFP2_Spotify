# %%
import pandas as pd
import json

# %%
with open('mpd.slice.0-999.json','r')as json_file:
    plists = json.load(json_file)

# %%
with open('artists_0-999.json','r')as json_file:
    artists = json.load(json_file)

# %%
artists
# Out:
# {'2wIVse2owClT7go1WT98tk': {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#   'followers': {'href': None, 'total': 2386591},
#   'genres': ['dance pop',
#    'hip hop',
#    'hip pop',
#    'neo soul',
#    'pop rap',
#    'r&b',
#    'rap',
#    'urban contemporary',
#    'virginia hip hop'],
#   'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#   'id': '2wIVse2owClT7go1WT98tk',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebf6691f40d906f097e9fbaa4c',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174f6691f40d906f097e9fbaa4c',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178f6691f40d906f097e9fbaa4c',
#     'width': 160}],
#   'name': 'Missy Elliott',
#   'popularity': 70,
#   'type': 'artist',
#   'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'},
# ...

# %%
artists['2wIVse2owClT7go1WT98tk']['genres']
# Out:
# ['dance pop',
#  'hip hop',
#  'hip pop',
#  'neo soul',
#  'pop rap',
#  'r&b',
#  'rap',
#  'urban contemporary',
#  'virginia hip hop']

# %%
artists['26bcq2nyj5GB7uRr558iQg']['genres']
# Out:
# ['album rock', 'glam metal', 'hard rock', 'soft rock']

# %%
for playlist in plists['playlists']:
    #print(f"Playlist: {playlist['name']}")
    for track in playlist['tracks']:
        uri = track['artist_uri']
        uri = uri.split(":")[2]
        print(uri)

# %%
plists['playlists'][1]['tracks'][0]
# Out:
# {'pos': 0,
#  'artist_name': 'Survivor',
#  'track_uri': 'spotify:track:2HHtWyy5CgaQbC7XSoOb0e',
#  'artist_uri': 'spotify:artist:26bcq2nyj5GB7uRr558iQg',
#  'track_name': 'Eye of the Tiger',
#  'album_uri': 'spotify:album:4PT9VulQaQP6XR1xBI2x1W',
#  'duration_ms': 243773,
#  'album_name': 'Eye Of The Tiger'}

# %%
for playlist in plists['playlists']:
    #print(f"Playlist: {playlist['name']}")
    for track in playlist['tracks']:
        uri = track['artist_uri']
        uri = uri.split(":")[2]
        print(uri)
# Out:
# 2wIVse2owClT7go1WT98tk
# 26dSoYclwsYLMAKD3tpOr4
# 6vWDO969PvNqNYHIOW5v0m
# 31TPClRtHm23RisEBtV3X7
# 5EvFsr3kj42KNv97ZEnqij
# 23zg3TcAtWQy7J6upgbUnj
# 23zg3TcAtWQy7J6upgbUnj
# 6wPhSqRtPu1UhRCDX5yaDJ
# 1Y8cdNmUJH7yBTd9yOvr5i
# 1G9G7WwrXka3Z1r7aIDjI7
# 2jw70GZXlAI8QzWeY2bgRc
# 2Hjj68yyUPiC0HKEOigcEp
# 2Hjj68yyUPiC0HKEOigcEp
# 2Hjj68yyUPiC0HKEOigcEp
# 27FGXRNruFoOdf1vP8dqcH
# 0f5nVCcR06GX8Qikz0COtT
# 0p4nmQO2msCgU4IF37Wi3j
# 7bXgB6jMjp9ATFy66eO08Z
# 6vWDO969PvNqNYHIOW5v0m
# 1Y8cdNmUJH7yBTd9yOvr5i
# 4TKTii6gnOnUXQHyuo9JaD
# 1yxSLGMDHlW21z4YXirZDS
# 5ND0mGcL9SKSjWIjPd0xIb
# 01lz5VBfkMFDteSA9pKJuP
# 7bXgB6jMjp9ATFy66eO08Z
# 7gOdHgIoIKoe4i9Tta6qdD
# 5qK5bOC6wLtuLhG5KvU17c
# 0N0d3kjwdY2h7UVuTdJGfp
# 07YZf4WDAMNwqr4jfgOZ8y
# 21E3waRsmPlU7jZsS13rcj
# 5YGY8feqx7naU7z4HrwZM6
# 0vWCyXMrrvMlCcepuOJaGI
# 5tKXB9uuebKE34yowVaU3C
# 7bXgB6jMjp9ATFy66eO08Z
# 6LqNN22kT3074XbTVUrhzX
# 21E3waRsmPlU7jZsS13rcj
# 1uNFoZAHBGtllmzznpCI3s
# 0QJIPDAEDILuo8AIq3pMuU
# 0C0XlULifJtAgn6ZNCW2eu
# 6FBDaR13swtiWwGhX1WQsP
# ...

# %%
with open('artists_0-999.json','r')as json_file:
    data = json.load(json_file)

# %%
for artists in data['artists']:
    for
# Out:
#   File "C:\Users\sbarrera\AppData\Local\Temp\ipykernel_25840\3138342727.py", line 1
#     for gener in data['artists']:
#                                  ^
# IndentationError: expected an indented block

# %%
elliot = data["2wIVse2owClT7go1WT98tk"]["genres"]

# %%
spears = data["26dSoYclwsYLMAKD3tpOr4"]["genres"]

# %%
spears
# Out:
# ['dance pop', 'pop']

# %%
beyonce = data["6vWDO969PvNqNYHIOW5v0m"]["genres"]

# %%
beyonce
# Out:
# ['pop', 'r&b']
