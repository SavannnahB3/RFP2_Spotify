# %%
import pandas as pd
import json
from sklearn.cluster import MiniBatchKMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
with open('artists_0-999.json','r')as json_file:
    artists = json.load(json_file)

# %%
artists
# Out:
# {'2wIVse2owClT7go1WT98tk': {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#   'followers': {'href': None, 'total': 2386591},
#   'genres': ['dance pop',
#    'hip hop',
#    'hip pop',
#    'neo soul',
#    'pop rap',
#    'r&b',
#    'rap',
#    'urban contemporary',
#    'virginia hip hop'],
#   'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#   'id': '2wIVse2owClT7go1WT98tk',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebf6691f40d906f097e9fbaa4c',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174f6691f40d906f097e9fbaa4c',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178f6691f40d906f097e9fbaa4c',
#     'width': 160}],
#   'name': 'Missy Elliott',
#   'popularity': 70,
#   'type': 'artist',
#   'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'},
# ...

# %%
with open('Vetting_Playlist.json','r')as json_file:
    vetting = json.load(json_file)

# %%
vetting.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
vetting['tracks']['items'][6]['track']['artists'][0]['id']
# Out:
# '3nuc29fYGlQbIrwh4yrNWd'

# %%
listOfSongs = vetting['tracks']['items']

# %%
idx = 0
uri = []
for item in listOfSongs:
    uri.append(item['track']['artists'][0]['id'])

# %%
for i in range(len(uri)):
    artists[uri[i]]['genres'] 
    if uri in artists.keys():
        genres = artists[uri]['genres']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23068\3788297303.py in <module>
#       1 for i in range(len(uri)):
#       2     artists[uri[i]]['genres']
# ----> 3     if uri in artists.keys():
#       4         genres = artists[uri]['genres']
#
# TypeError: unhashable type: 'list'
